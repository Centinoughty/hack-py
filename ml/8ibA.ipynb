# %%
# !pip install PyPDF2
# !pip install  pandas
# !pip install nltk
# !pip install transformers
# !pip install torch
# !pip install sentencepiece
# !pip install ipywidgets
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: PyPDF2 in ./venv/lib/python3.10/site-packages (3.0.1)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pandas in ./venv/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in ./venv/lib/python3.10/site-packages (from pandas) (2.2.1)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: nltk in ./venv/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in ./venv/lib/python3.10/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: tqdm in ./venv/lib/python3.10/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: regex>=2021.8.3 in ./venv/lib/python3.10/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: joblib in ./venv/lib/python3.10/site-packages (from nltk) (1.4.2)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in ./venv/lib/python3.10/site-packages (4.47.1)
# Requirement already satisfied: tqdm>=4.27 in ./venv/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in ./venv/lib/python3.10/site-packages (from transformers) (0.27.0)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: numpy>=1.17 in ./venv/lib/python3.10/site-packages (from transformers) (2.2.1)
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: requests in ./venv/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./venv/lib/python3.10/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: pyyaml>=5.1 in ./venv/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in ./venv/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in ./venv/lib/python3.10/site-packages (from transformers) (0.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.10/site-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.10/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.10/site-packages (from requests->transformers) (3.4.1)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: torch in ./venv/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./venv/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: networkx in ./venv/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./venv/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from torch) (3.16.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./venv/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: sympy==1.13.1 in ./venv/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./venv/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./venv/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: fsspec in ./venv/lib/python3.10/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./venv/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./venv/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: triton==3.1.0 in ./venv/lib/python3.10/site-packages (from torch) (3.1.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./venv/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.10/site-packages (from torch) (3.1.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./venv/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: sentencepiece in ./venv/lib/python3.10/site-packages (0.2.0)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: ipywidgets in ./venv/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: ipython>=6.1.0 in ./venv/lib/python3.10/site-packages (from ipywidgets) (8.31.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./venv/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in ./venv/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in ./venv/lib/python3.10/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in ./venv/lib/python3.10/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: decorator in ./venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in ./venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: typing_extensions>=4.6 in ./venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: exceptiongroup in ./venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: stack_data in ./venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in ./venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in ./venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in ./venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.1.0)

# %%
from PyPDF2 import PdfReader
import pandas as pd
import re
import nltk
from nltk.tokenize import sent_tokenize
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer, pipeline, AutoModelForSeq2SeqLM, AutoTokenizer, AutoConfig

# %%
nltk.download("punkt")
model_name = "mrm8488/t5-base-finetuned-question-generation-ap"  # Or a different text-to-text model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
qa_generator = pipeline('text2text-generation', model=model, tokenizer=tokenizer)
qa_pipeline = pipeline("question-answering")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Device set to use cuda:0
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
# Extract text from PDF

def extract_text(pdf_paths):
    text_data = []
    for pdf_path in pdf_paths:
        reader = PdfReader(pdf_path)
        full_text = ""
        for page in reader.pages:
            full_text += page.extract_text()

        text_data.append(full_text)
    return text_data

# %%
def process_text(text):
    text = re.sub(r'\s+', ' ', text)  # Remove excessive spaces
    text = re.sub(r'[^\x00-\x7f]', ' ', text)  # Remove non-ASCII characters
    return text.strip()

# %%
def segment_text(txt, sentences_per_segment=7):
    sentences = sent_tokenize(txt)  # This expects 'txt' to be a string
    segments = []
    
    # Create segments of 'sentences_per_segment' sentences
    for i in range(0, len(sentences), sentences_per_segment):
        segment = sentences[i:i + sentences_per_segment]
        segments.append(" ".join(segment))
    
    return segments

# %%
def generate_qp_pairs_from_segments(segments):
    qa_dataset = []
    count = 0
    for paragraph in segments:
        try:
            # Generate questions using the paragraph as input
            generated_questions = qa_generator(paragraph, max_length=100)
            for generated_question_data in generated_questions:
                try:
                    question = generated_question_data['generated_text']
                    answer_data = qa_pipeline({"question": question, "context": paragraph},padding=True, 
                      truncation=True, 
                      max_length=256, 
                      stride=128)
                    print(f"Generated question {count}: {question}")

                    count = count + 1
                    # The answer is in generated_questions
                    answer = answer_data['answer']
                    qa_dataset.append({"Question": question, "Answer": answer})

                except Exception as inner_e:
                    print(f"Error getting answer for question: {question}\n{inner_e}")
        except Exception as outer_e:
            print(f"Error generating questions for paragraph: {paragraph}\n{outer_e}")
    return qa_dataset

# %%
def save_csv(qp_pairs, output_path):
    df = pd.DataFrame(qp_pairs, columns=["Question", "Answer"])
    df.to_csv(output_path)
    print(f"CSV saved at {output_path}")

# %%
pdf_paths = ["textbook1.pdf", "textbook2.pdf", "textbook3.pdf"]
text = extract_text(pdf_paths)

# %%
pdf_pathsed = ["textbook1.pdf"]
texted = extract_text(pdf_pathsed)

# %%
combined_text = " ".join(text)

segments = segment_text(combined_text, sentences_per_segment=7)

# %%
qp_pairs = generate_qp_pairs_from_segments(segments)
# Out:
# Generated question 0: : . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Generated question 1: Interpretation of Statutes is an important pre-requisite for professional assignments.
# Generated question 2: is part of the educational kit and takes the students through each phase of preparation.
# Generated question 3: ICSI Journal Chartered Secretary is available at the Institute..edu.au.
# Generated question 4: Writ Jurisdiction of High Court and Supreme Court l Different types of writs 4. Administrative Laws : l Conceptual Analysis l Source and Need of Administrative Law l Administrative Discretion l Administrative Discretion l Administrative Discretion l Administrative Law of a Corporation l Torts and Vicarious Liability l Torts and wrongs to personal safety and freedom l Torts and
# Generated question 5: question: What is the definition of a law relating to Civil Procedure?
# Generated question 6: question: What is the definition of the Law relating to Registration of Documents?
# Generated question 7: Constitution of India 3. Interpretation of Statutes 4. Administrative Laws 5. Law of Torts 6. Law relating to Civil Procedure 7. Law relating to Crime and its Procedure 8. Law relating to Crime and its Procedure 9. Law relating to Crime and its Procedure 9. Law relating to Crime and its Procedure 9. Law relating to Crime and its Procedure 9. Law relating to Crime and its Procedure 9. Law relating to Crime and its Procedure 9. Law relating to Crime and its
# Generated question 8: to Evidence 9. Law relating to Specific Relief 10. Law relating to Limitation 11. Law relating to Arbitration, Mediation and Conciliation 12. Law relating to Arbitration, Mediation, Mediation and Conciliation 13. Law relating to Registration of Documents 14. Right to Information Law 15.
# Generated question 9: question: What is the law relating to Information Technology?
# Generated question 10: question: What is the objective of the lesson?
# Generated question 11: Parliamentary Standing Committees and their Role. Lesson 3: Interpretation of Statutes.
# Generated question 12: question: What is the purpose of Lesson 5: Law of Torts?
# Generated question 13: question: What is the objective of the lesson?
# Generated question 14: Lesson 8: Law relating to Evidence: What is the law of evidence?
# Generated question 15: question: What is the lesson about the specific relief act?
# Generated question 16: question: What is the objective of the lesson?
# Generated question 17: question: What is the objective of the lesson?
# Generated question 18: question: What is the purpose of the lesson?
# Generated question 19: question: What is the lesson on Electronic Commerce designed to familiarize students with?
# Generated question 20: question: What is the lesson on Negotiable Instruments?
# Generated question 21: LESSON 3 ADMINISTRATIVE LAWS Introduction to Law of Torts – Conceptual Analysis 134 Need for interpretation of a statute 160 Kinds of Tortious Liability & General Conditions 161 Exceptions to the Rule of Strict Liability 162 Applicability of the rule in Rylands v. Fletcher 176 LESSON 4 LAW OF TORTS Introduction to Law of Torts – Concept
# Generated question 22: question: What is the LESSON 17 LAW RELATING TO STAMFORD LAW?
# Generated question 23: question: What is the legal system of India?
# Generated question 24: question: What is the definition of law in India?
# Generated question 25: Law is not static. As circumstances and conditions change, laws are also changed to fit the requirements of society.
# Generated question 26: The idea of abstract justice has been replaced by social justice.
# Generated question 27: It is necessary for civil society to function to its full potential. But only if it supports and empowers.
# Generated question 28: the analysis of rights, duties and obligations is a part of jurisprudence.
# Generated question 29: question: What is the main purpose of the term jurisprudence?
# Generated question 30: emphasizes the limitations of pure science of law. emphasizes the limitations of pure science of law. Sociological jurisprudence highlights the limitations of pure science of law.
# Generated question 31: question: What is the broadest sense of jurisprudence?
# Generated question 32: Bentham also distinguished between ‘censorial’ and ‘expository’ jurisprudence. Bentham also distinguished between ‘authoritative’ and ‘unauthoritative’ modes.
# Generated question 33: question: What is the task of jurisprudence to study the nature of law?
# Generated question 34: the normative legal theory and the positive legal theory are two prominent legal theories.
# Generated question 35: question: What is the source of a law?
# Generated question 36: question: What are the goals of a law's objects?
# Generated question 37: question: What is the direct extent of a law?
# Generated question 38: question: What motivates people to obey a law?
# Generated question 39: In addition to integrality, unity and unity, Bentham said that a law is complete when it has all the features of integrality and unity.
# Generated question 40: Bentham believed customs could never be ‘complete’. laws could never be eliminated by having ‘complete laws’.
# Generated question 41: question: What is the Command Theory of Law?
# Generated question 42: Austin believes that law is the command of a sovereign that is backed by sanction.
# Generated question 43: 2. It has a sanction behind it. Austin's theory of law.
# Generated question 44: According to Austin, the sovereign is the source of all laws.
# Generated question 45: According to Austin, the sovereign does not have to obey anyone but modern states have their powers limited by national and international laws and norms.
# Generated question 46: question: What did John William Salmond believe was the purpose of law?
# Generated question 47: question: What does Salmond say law is the body of principles which are recognized and applied by the state in the administration of justice?
# Generated question 48: compulsion is necessary to maintain justice. According to Salmond, if a just society is to be maintained, it needs to add compulsion.
# Generated question 49: The administration of justice was the primary task of a state and the laws were made to achieve that objective.
# Generated question 50: Salmond says that the substitution of rigid pre-established principles for individual judgment is a product of fit.
# Generated question 51: 1. The pursuit of justice is not the only purpose of law. 2. The pursuit of justice is not the only purpose of law. 3. The contradiction when Salmond says that the purpose of law is the administration of justice is a universal concept. 4. The contradiction when Pound says that the purpose of law is the administration of justice.
# Generated question 52: according to Roscoe Pound, an efficient society would require balancing of competing interests.
# Generated question 53: interests within the limits as defined. defined. 4. Securing of those interests within the limits as defined. 3. Securing of those interests within the limits as defined. According to Roscoe Pound, the following five things are required: 1. Preparation of an inventory of interests and their classification. 2. Selection of the interests which should be legally recognized. 3. Selection of the interests which should be legally recognized. 4. Selection of the interests which should be legally recognized. 5. Selection of
# Generated question 322: ut res magis valeat quam pereat.. a court can depart from the dictionary meaning of a word and give it a meaning which will advance the remedy and suppress the mischief.
# Generated question 323: The Court must interpret according to the purpose, policy, or spirit of the statute.
# Generated question 324: in the Act, each clause and each word must fit into the scheme of the entire Act.
# Generated question 325: at 203. of harmonius construction is known as the rule of harmonius construction.
# Generated question 326: question: What is the rule of ejusdem generis?
# Generated question 327: question: What is the option of Heydon's rule?
# Generated question 328: question: What is the maxim that a contemporaneous exposition is the best and strongest in law?
# Generated question 329: the correct meaning will be given by the Courts except when title to property may be affected or everyday transactions have been entered into on such wrong interpretation.
# Generated question 330: question: When the intent of the legislature in associating wider words with words of narrower significance is doubtful that the present rule of construction can be usefully applied?
# Generated question 331: LESSON 3 Interpretation of Statutes103 (d) Strict and Liberal Construction
# Generated question 332: question: What is a strong presumption that a statute does not intend to attach liability without a guilty intent?
# Generated question 333: a state is not affected by a statute unless it is expressly mentioned as being so affected. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Generated question 334: The Court will not even alter an obvious one unless it is to correct a faulty one. (i) That the legislature does not make mistakes. (j) The law compels no man to do that which is futile or fruitless. (k) The law compels no man to do that which is futile or fruitless.
# Generated question 335: AIDS TO INTERPRETATION In determining the meaning of an Act, it is permissible to consider two points: (1) The external evidence derived from extraneous circumstances, such as, previous legislation and decided cases etc., and (2) The internal evidence derived from the Act itself.
# Generated question 336: question: What is the true place of a preamble in a statute?
# Generated question 337: question: What is the modern rule between the two extremes?
# Generated question 338: question: What is the preamble treated as a key for the interpretation of a statute?
# Generated question 339: question: What did Lord Goddard say in his opinion?
# Generated question 340: question: What is the weight of authority in favor of the view that the marginal note appended to a section cannot be used for construing the section?
# Generated question 341: question: What is the purpose of marginal notes to sections of the Constitution?
# Generated question 342: marginal note is permissible in law. in all types of cases. Section of a statute may borrow definitions from earlier Acts. or extensive of the same.
# Generated question 343: question: What form of a definition is understood as extensive?
# Generated question 344: question: What is the purpose of a proviso?
# Generated question 345: question: What is an illustration of a statute?
# Generated question 346: an explanation may have been added ex abundanti cautela to allay groundless apprehension. Schedules and enactments are part of the statute and must be read together for all purposes of construction.
# Generated question 347: question: What is the rule of interpretation for the enacting part and the schedule?
# Generated question 348: question: What is the purpose of the statute if it is not ambiguous?
# Generated question 349: LESSON 3 Interpretation of Statutes109.
# Generated question 350: ambiguity or uncertainty in a provision of a statute may be regarded by the Court for ascertaining the intention behind the provision.
# Generated question 351: question: What is the meaning of the word pari materia?
# Generated question 352: question: What is the question of construction of a repealed statute?
# Generated question 353: regulations can not alter or vary the meaning of words of a statute.
# Generated question 354: question: What is the use of Marginal Notes?
# Generated question 355: question: What is the term for a mixed action?
# Generated question 356: : At the same point. Ad idem: At the same point.
# Generated question 357: : What is the caveat emptor?
# Generated question 358: Corpus delicti : Body/gist of the offence. De jure : By right. De jure : By right.
# Generated question 359: power cannot be further delegated. Delegatus non potest delegare : A delegate cannot delegate. Delegatus non potest delegare : A delegate cannot delegate.
# Generated question 360: Ex parte : Proceedings in the absence of the other party. Ex parte : Proceedings in the absence of the other party. Ex parte : Proceedings in the absence of the other party. Ex parte : Proceedings in the absence of the other party. Ex parte : Proceedings in the absence of the other party.
# Generated question 361: probans : Relevant fact. Factum probans : Relevant fact. Force majeure : Force majeure by nature.
# Generated question 362: question: What is the state or public interest requiring that there should be a limit to litigation?
# Generated question 363: : Between living persons. Intra vires : Within the powers. Intra vires : Between living persons. Intra vires : Within the powers.
# Generated question 364: in personam : Right against a person. Jus in rem : Right against the world at large.
# Generated question 365: question: What is a mala fide?
# Generated question 366: a sociis : A word is known by its associated, a sociis is known by its companions. Onus Probandi : On equal footing or proportional basis.
# Generated question 367: Per incuriam : Through want of care; through inadvertentness. Per forma : As a matter of form. Pro rata : In proportion. Posteriori : From the consequences to the antecendent.
# Generated question 368: Puisne mortgage : Second mortgage. : Second mortgage. Puisne mortgage : Second mortgage.
# Generated question 369: question: What is the rule that must be final unless cause is shown against it?
# Generated question 370: Status quo : The current state of things at any given date.
# Generated question 371: :: Simply; without any addition. Scienter: Knowing circumstances is necessary to make one liable. Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter: Scienter
# Generated question 372: question: What is a right that can be remedied without contract?
# Generated question 373: question: What is the meaning of the word "valat?"
# Generated question 374: question: What is the purpose of reading a bare act?
# Generated question 375: Reading the entire sentence would be beneficial. 7. Read the updated version of the bare act 6. Read the updated version of the bare act 7. Literal interpretation would be beneficial 8. Read – understand – apply rule would be beneficial 9.
# Generated question 376: the law reports used by the professionals in their pleadings are as follows: 1. All India Reporter (AIR) 2. Supreme Court Cases (SCJ) 4. Supreme Court Reports (SCR) 5. Delhi Law Times (DLT) Equivalent Citation is also important to refer the cases which means parallel citations.
# Generated question 377: are used to refer to the citations of same cases published in other journal.
# Generated question 378: question: What language suggests that a person continuing to be a director till the date of commencement of the amendment act?
# ...
# Generated question 1231: question: What is the principle of unstamped instruments being admissible in evidence even for collateral purposes?
# Generated question 1232: CERTAIN REGISTERED DOCUMENTS RELATING TO LAND WILL TAKE EFFECT AGAINST UNREGISTERED DOCUMENTS?
# Generated question 1233: question: What particulars shall be endorsed on documents admitted to registration?
# Generated question 1234: Registrar shall forward a copy of the document to other registrars. Registrar shall file in Book No. 1 and send a copy of the document to other registrars.
# Generated question 1235: question: What are the pre-requisits for registration of documents?
# Generated question 1236: question: What is the time limit for a document to be presented for registration?
# Generated question 1237: question: What is the time limit for a will to be presented for registration?
# Generated question 1238: question: Who can present the document for registration?
# Generated question 1239: question: What shall be affixed to the sale deed?
# Generated question 1240: and driving licence are required now.
# Generated question 1241: 73(2) APPEAL TO Registrar .
# Generated question 1242: the document to be registered in the Civil Court. a suit for a decree directing the document to be registered in the office in which the document is sought to be registered.
# Generated question 1243: of occupants or of land by holders of such land. ACT AND REGISTRATION OF DOCUMENTS.
# Generated question 1244: sale in execution, forfeiture, insolvency or intestate succession are not included in the Transfers by operation of law.
# thread '<unnamed>' panicked at /home/runner/work/tokenizers/tokenizers/tokenizers/src/tokenizer/encoding.rs:319:9:
# `stride` must be strictly less than `max_len=57` (note that `max_len` may be shorter than the max length of the original model, as it subtracts the number of special characters
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 qp_pairs = generate_qp_pairs_from_segments(segments)
#
# Cell In[103], line 11, in generate_qp_pairs_from_segments(segments)
#       9 try:
#      10     question = generated_question_data['generated_text']
# ---> 11     answer_data = qa_pipeline({"question": question, "context": paragraph},padding=True,
#      12       truncation=True,
#      13       max_length=256,
#      14       stride=128)
#      15     print(f"Generated question {count}: {question}")
#      17     count = count + 1
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/pipelines/question_answering.py:398, in QuestionAnsweringPipeline.__call__(self, *args, **kwargs)
#     396 examples = self._args_parser(*args, **kwargs)
#     397 if isinstance(examples, (list, tuple)) and len(examples) == 1:
# --> 398     return super().__call__(examples[0], **kwargs)
#     399 return super().__call__(examples, **kwargs)
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1293, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1291     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1292 elif self.framework == "pt" and isinstance(self, ChunkPipeline):
# -> 1293     return next(
#    1294         iter(
#    1295             self.get_iterator(
#    1296                 [inputs], num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1297             )
#    1298         )
#    1299     )
#    1300 else:
#    1301     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/pipelines/pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/pipelines/pt_utils.py:269, in PipelinePackIterator.__next__(self)
#     266             return accumulator
#     268 while not is_last:
# --> 269     processed = self.infer(next(self.iterator), **self.params)
#     270     if self.loader_batch_size is not None:
#     271         if isinstance(processed, torch.Tensor):
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:33, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      31 for _ in possibly_batched_index:
#      32     try:
# ---> 33         data.append(next(self.dataset_iter))
#      34     except StopIteration:
#      35         self.ended = True
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/pipelines/pt_utils.py:186, in PipelineChunkIterator.__next__(self)
#     183     self.subiterator = self.infer(next(self.iterator), **self.params)
#     184 try:
#     185     # Try to return next item
# --> 186     processed = next(self.subiterator)
#     187 except StopIteration:
#     188     # When a preprocess iterator ends, we can start lookig at the next item
#     189     # ChunkIterator will keep feeding until ALL elements of iterator
#    (...)
#     192     # Another way to look at it, is we're basically flattening lists of lists
#     193     # into a single list, but with generators
#     194     self.subiterator = self.infer(next(self.iterator), **self.params)
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/pipelines/question_answering.py:431, in QuestionAnsweringPipeline.preprocess(self, example, padding, doc_stride, max_question_len, max_seq_len)
#     427 else:
#     428     # Define the side we want to truncate / pad and the text/pair sorting
#     429     question_first = self.tokenizer.padding_side == "right"
# --> 431     encoded_inputs = self.tokenizer(
#     432         text=example.question_text if question_first else example.context_text,
#     433         text_pair=example.context_text if question_first else example.question_text,
#     434         padding=padding,
#     435         truncation="only_second" if question_first else "only_first",
#     436         max_length=max_seq_len,
#     437         stride=doc_stride,
#     438         return_token_type_ids=True,
#     439         return_overflowing_tokens=True,
#     440         return_offsets_mapping=True,
#     441         return_special_tokens_mask=True,
#     442     )
#     443     # When the input is too long, it's converted in a batch of inputs with overflowing tokens
#     444     # and a stride of overlap between the inputs. If a batch of inputs is given, a special output
#     445     # "overflow_to_sample_mapping" indicate which member of the encoded batch belong to which original batch sample.
#     446     # Here we tokenize examples one-by-one so we don't need to use "overflow_to_sample_mapping".
#     447     # "num_span" is the number of output samples generated from the overflowing tokens.
#     448     num_spans = len(encoded_inputs["input_ids"])
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2860, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2858     if not self._in_target_context_manager:
#    2859         self._switch_to_input_mode()
# -> 2860     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2861 if text_target is not None:
#    2862     self._switch_to_target_mode()
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2970, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    2948     return self.batch_encode_plus(
#    2949         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2950         add_special_tokens=add_special_tokens,
#    (...)
#    2967         **kwargs,
#    2968     )
#    2969 else:
# -> 2970     return self.encode_plus(
#    2971         text=text,
#    2972         text_pair=text_pair,
#    2973         add_special_tokens=add_special_tokens,
#    2974         padding=padding,
#    2975         truncation=truncation,
#    2976         max_length=max_length,
#    2977         stride=stride,
#    2978         is_split_into_words=is_split_into_words,
#    2979         pad_to_multiple_of=pad_to_multiple_of,
#    2980         padding_side=padding_side,
#    2981         return_tensors=return_tensors,
#    2982         return_token_type_ids=return_token_type_ids,
#    2983         return_attention_mask=return_attention_mask,
#    2984         return_overflowing_tokens=return_overflowing_tokens,
#    2985         return_special_tokens_mask=return_special_tokens_mask,
#    2986         return_offsets_mapping=return_offsets_mapping,
#    2987         return_length=return_length,
#    2988         verbose=verbose,
#    2989         split_special_tokens=split_special_tokens,
#    2990         **kwargs,
#    2991     )
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:3046, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3036 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3037 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3038     padding=padding,
#    3039     truncation=truncation,
#    (...)
#    3043     **kwargs,
#    3044 )
# -> 3046 return self._encode_plus(
#    3047     text=text,
#    3048     text_pair=text_pair,
#    3049     add_special_tokens=add_special_tokens,
#    3050     padding_strategy=padding_strategy,
#    3051     truncation_strategy=truncation_strategy,
#    3052     max_length=max_length,
#    3053     stride=stride,
#    3054     is_split_into_words=is_split_into_words,
#    3055     pad_to_multiple_of=pad_to_multiple_of,
#    3056     padding_side=padding_side,
#    3057     return_tensors=return_tensors,
#    3058     return_token_type_ids=return_token_type_ids,
#    3059     return_attention_mask=return_attention_mask,
#    3060     return_overflowing_tokens=return_overflowing_tokens,
#    3061     return_special_tokens_mask=return_special_tokens_mask,
#    3062     return_offsets_mapping=return_offsets_mapping,
#    3063     return_length=return_length,
#    3064     verbose=verbose,
#    3065     split_special_tokens=kwargs.pop("split_special_tokens", self.split_special_tokens),
#    3066     **kwargs,
#    3067 )
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/tokenization_utils_fast.py:600, in PreTrainedTokenizerFast._encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#     576 def _encode_plus(
#     577     self,
#     578     text: Union[TextInput, PreTokenizedInput],
#    (...)
#     597     **kwargs,
#     598 ) -> BatchEncoding:
#     599     batched_input = [(text, text_pair)] if text_pair else [text]
# --> 600     batched_output = self._batch_encode_plus(
#     601         batched_input,
#     602         is_split_into_words=is_split_into_words,
#     603         add_special_tokens=add_special_tokens,
#     604         padding_strategy=padding_strategy,
#     605         truncation_strategy=truncation_strategy,
#     606         max_length=max_length,
#     607         stride=stride,
#     608         pad_to_multiple_of=pad_to_multiple_of,
#     609         padding_side=padding_side,
#     610         return_tensors=return_tensors,
#     611         return_token_type_ids=return_token_type_ids,
#     612         return_attention_mask=return_attention_mask,
#     613         return_overflowing_tokens=return_overflowing_tokens,
#     614         return_special_tokens_mask=return_special_tokens_mask,
#     615         return_offsets_mapping=return_offsets_mapping,
#     616         return_length=return_length,
#     617         verbose=verbose,
#     618         split_special_tokens=split_special_tokens,
#     619         **kwargs,
#     620     )
#     622     # Return tensor is None, then we can remove the leading batch axis
#     623     # Overflowing tokens are returned as a batch of output so we keep them in this case
#     624     if return_tensors is None and not return_overflowing_tokens:
#
# File /workspace/nadeem_b230440cs/venv/lib/python3.10/site-packages/transformers/tokenization_utils_fast.py:526, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens)
#     523 if self._tokenizer.encode_special_tokens != split_special_tokens:
#     524     self._tokenizer.encode_special_tokens = split_special_tokens
# --> 526 encodings = self._tokenizer.encode_batch(
#     527     batch_text_or_text_pairs,
#     528     add_special_tokens=add_special_tokens,
#     529     is_pretokenized=is_split_into_words,
#     530 )
#     532 # Convert encoding to dict
#     533 # `Tokens` has type: Tuple[
#     534 #                       List[Dict[str, List[List[int]]]] or List[Dict[str, 2D-Tensor]],
#     535 #                       List[EncodingFast]
#     536 #                    ]
#     537 # with nested dimensions corresponding to batch, overflows, sequence length
#     538 tokens_and_encodings = [
#     539     self._convert_encoding(
#     540         encoding=encoding,
#    (...)
#     549     for encoding in encodings
#     550 ]
#
# PanicException: `stride` must be strictly less than `max_len=57` (note that `max_len` may be shorter than the max length of the original model, as it subtracts the number of special characters

# %%
save_csv(qp_pairs, "temp5.csv")
# Out:
# CSV saved at temp5.csv
